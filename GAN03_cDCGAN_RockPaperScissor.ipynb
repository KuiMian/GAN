# %% [markdown]
# **Train cDCGAN with Rock-Paper-Scissor Dataset**
#
# ---
#
# You can get dataset from [Rock-Paper-Scissor, Kaggle](https://www.kaggle.com/datasets/sanikamal/rock-paper-scissors-dataset).

# %%
import numpy as np
import pandas as pd
import plotly.express as px

import torch
import torch.nn as nn
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import DataLoader, Subset

from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torchvision import transforms as T

from tqdm import trange, tqdm

from IPython.display import clear_output

from multiprocessing import cpu_count

# %%
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

img_size = 128
img_dim = img_size ** 2
img_channels = 3
n_class = 3

z_dim = 100

n_epochs = 50
batch_size = 32
lr = 4e-4
k= 25 # G_lr/D_lr

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
print(f"Cpu core num: {cpu_count()}")
# Out:
# Using device: cuda
# Cpu core num: 2

# %%
def download_dataset_to_dir(dataset_id: str, move: bool = True, target_dir: str = "./data/"):
    """
    使用 kagglehub 下载 Kaggle 数据集，并移动/复制到指定目录
    :param dataset_id: Kaggle 数据集 ID，比如 "splcher/animefacedataset"
    :param move: True=剪切数据至target_dir，False=数据位置不变
    :param target_dir: 目标目录，比如 "./data"
    :return: 目标目录的绝对路径
    """

    import kagglehub
    import shutil
    import os

    # 下载/获取缓存路径
    cache_path = kagglehub.dataset_download(dataset_id)
    print(f"Download path: {cache_path}")

    if not move:
        return cache_path
    else:
        # 确保目标目录存在
        os.makedirs(target_dir, exist_ok=True)

        # 移动内容
        for item in os.listdir(cache_path):
            s = os.path.join(cache_path, item)
            d = os.path.join(target_dir, item)

            # 剪切（移动）
            if os.path.exists(d):
                if os.path.isdir(d):
                    shutil.rmtree(d)
                else:
                    os.remove(d)
            shutil.move(s, d)

        return os.path.abspath(target_dir)

data_path = download_dataset_to_dir("sanikamal/rock-paper-scissors-dataset", move=False, target_dir="./data/rockpaperscissors/")
# Out:
# Using Colab cache for faster access to the 'rock-paper-scissors-dataset' dataset.
# Download path: /kaggle/input/rock-paper-scissors-dataset

# %%
train_dataset = ImageFolder(root=data_path + '/Rock-Paper-Scissors/train', transform=T.Compose(
        [
            T.Resize(img_size),
            T.ToTensor(),
            T.Normalize([0.5] * 3, [0.5] * 3),
        ]
    ))

subset_flag = False
subset_size = 2000

data_loader_paras = {
    "batch_size": batch_size,
    "shuffle": True,
    "drop_last": True,

    "num_workers": 2,
    "pin_memory": True,
}

if subset_flag:
    indices = np.random.choice(range(len(train_dataset)), subset_size)
    subset_dataset = Subset(train_dataset, indices)
    print(f"Subset dataset size: {len(subset_dataset)}")

    train_loader = DataLoader(subset_dataset, **data_loader_paras)
else:
    train_loader = DataLoader(train_dataset, **data_loader_paras)

n_samples = len(train_loader.dataset)
n_batches = len(train_loader)
print(f"Number of training samples: {n_samples}")
print(f"Number of batches: {n_batches}")
# Out:
# Number of training samples: 2520
# Number of batches: 78

# %%
imgs, labels = next(iter(train_loader))
print(f"Image batch shape: {imgs.shape}")
print(f"Label batch shape: {labels.shape}")
# Out:
# Image batch shape: torch.Size([32, 3, 128, 128])
# Label batch shape: torch.Size([32])

# %%
from IPython.display import display, HTML

def show_centered(fig):
    html = f"<div style='display:flex; justify-content:center;'>{fig.to_html(include_plotlyjs='cdn')}</div>"
    display(HTML(html))

# %%
def denormalize(imgs):
    return imgs * 0.5 + 0.5

def show_images(imgs, grid_size=5):
    grid_imgs = make_grid(denormalize(imgs)[:24], nrow=6, padding=2).permute(1, 2, 0)

    fig = px.imshow(grid_imgs, aspect='auto')
    fig.update_xaxes(showticklabels=False).update_yaxes(showticklabels=False)
    fig.update_layout(
        width=800,
        height=400,
        title=dict(
            text="Rock-Paper-Scissor",
            x=0.5,
            xanchor='center',
            yanchor='top',
        ),
        coloraxis_showscale=False,
    )

    show_centered(fig)

show_images(imgs)
# Out:
# <div style='display:flex; justify-content:center;'><html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8ba6c445-ce62-4119-9fbf-7f51d6d2bb7b" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ba6c445-ce62-4119-9fbf-7f51d6d2bb7b")) {                    Plotly.newPlot(                        "8ba6c445-ce62-4119-9fbf-7f51d6d2bb7b",                        [{"name":"0","source":"data:image\u002fpng;base64,...\u002fUmzinrVdXZYzO7n31+bubE5ObpK669ZtPWLUlVXfpUSJUmGxI\u002fEqdUO9b4SDQnRk2ZWHwDG9jAq4XqmKrSaZhXUR2G6VSw9pB\u002f7VA1JllbSyYL07HWqFqypjMdN\u002fCjgmpAvry+Wy3yq8y1k2swX0U0Q7ca3rW2V92yGqphX0Pz6hyPUW2zyGiqhMY5JdEvD0lbtZ3VKpoCkThlTxw7dOgv\u002f+1\u002ffPqu+4f9wkx23\u002f7Xf\u002fI3\u002fsn\u002fNDk1lRpZL7AmxppX1TNWba0DVqs0FYyuT3Q6bmADGzhjqA72arKG5mAfexJ41bFavVVm5EeiJp+EU+vGFk9ZdW4Fa+du4AzjlXdHMwxqsdGMpWoyoannzCBaWw3vKlFDLbzXEAOgFdQlTgZXE0n65XlkbH1VTqJrYmMLjoWI7Hr0sZ133esXl+G9X1p+4gf3PL\...\u002fwB8eVjnsGqaoapjmenYHNcJp6x0tYIJa2holq1y1mNVU6CmoZKzFnMDry\u002fGhujpotazSWHiVwkdt\u002fT4qpgxFquprUXyak2ooml2RGxUs0iUj\u002fzVclHdq1TFGoNwNVTtq\u002fVBNRltjfyUG\u002fki8uJTTz\u002f7wMO95d702Wdd846bz7vk4tqLGLuefHzPAw\u002fEeZICsXFHdu259zvf+et\u002f+2+7LItiY9H0YM2SRJxW21OjqqWISEQSJxLVYyKaVm1gAz+WODOh3hxWaZin3Cri+F2Nk0Z3VSChqnk1nFJgNeURyZixYlVTozFry9fQlGlyNvDjhNi\u002f1eFQGxrN4VAtMjaYx46CGnOsTBWx3po91SJRoBbeTZ1V46vyYzmRqF6pEzOiKnzSVKnppleC2IzU4Grbxlp84siR2\u002f7Dfzr89Asiooafvum6v\u002fl\u002f\u002f2fnXnRhEvNl+cw93x\u002fOzxIsEylUAVUNw3LHD77\u002fnp\u002f56XPOvyBKNpHMqCbHOjryk7WndEhTQFWrTUt0U1vTgA1sYAOni+robo6pdM6p0kmsOX6rWDu3WVdEVf8rQfOMkZjVRtUwttQGNlBFLT6ro6PGrNLNqI78UwZ8MzcWqR5T3FaTsWDKWgNNG2rJVFdEYlYFqvyqAVhtW3e1fBXr59esrHKicCqSfHH4+RdOvLDbApbBwR949IlHf\u002fDDEEL0GhH1FhdO7N3FRETETBQpgIlmDx8+tHv3qKZxSLXjZJ9WjUnHNfwwlhOZtHp3xqya5mjDakU2sIENvHKk8RXPISdnjnJr\u002fFc+JJsVnS6ShprZtfNYItL5pMaPRBOv3MKXAVV9eZ\u002fLUtVer3fi+PHBYFDP28Dp4JSjoBpItSBsFlwjq8mpIQpUj5GoGpCwRiQnVJUkZizYLB4rqja8hsisFnzpu0qRaCqtYqxSNLwc7ajyE10lqvIicnzvPhQFW0sCMLz3T\u002f3wnhs++N5zzj8\u002fyveWFoe9RRgmEBFIwYSgqqp+MDy098Xr3\u002f2e1SysomZA1ZtNB1Uxll\u002fVEBsSmSIiIjG3WTDyU\u002fNruRvYwAbWQHW0VokmxmalMdtEdWCuJnO6SArHYmxuOqVglSZUs6rCVYwtGNEUfk2hIocPH3r4gfv7vd7bbnnnhRdfYoypC60CX5aPPPzg7V\u002f\u002fypHDBy5705s\u002f8ou\u002feunlV8SNGetHWZbzc3NLS4uGzeatWzqd7ulqeB2xRriuHzHMUthUk4lTlYxEzKrxXy2MDe9addWGr1F7VazakMSscapEpGvCTdteegC3hiOqjnsZqDY+cWrahv3+gSefhAqzEYAEDNm\u002f4+lvfPpTv\u002fZ\u002f\u002fr90JyYABO+DCDnLpESkBAUYUIAYxw8fCiFYO373VbPlVSR71mhjM6tZJNFpwhST1fZGP6eyTVdsYAMbWBurDeSENLKqkilZG3GnOwBral8hTqlqNfPWc+pIMusRTli\u002f5Dqx+8VdH\u002f1Pv\u002fPYA\u002feWRXHxFVf+o\u002f\u002f5f7n57besc7LywvPP\u002f9Hv\u002fvsDLz4XQvns4w\u002ftfPbJv\u002fuP\u002fudrr7\u002fBWlcXXQXz83O3ffmv7r7j2wtzM9a6iy674gM\u002f9XM33\u002fKuiYnJuugbEq9id4yN\u002f1oErnbZSseqTBVjx8VYZkKyZ+w4reLlRXJCtSEJkdNUWM1KzJfegEusJqp6mxirl4iSBdVjFUleVY\u002fs27Pv4QcJxMawMczEAMryibt+sOvpJ1JZLyRtS85Ya5wxzhhDIApksXTiuC\u002fLqG2lhhFUdWF+ft+uF48cOFgMh7XmJDMi0eykiNiilKzVUtNZZa6zJzawgQ28bKQxFYnqWI7DMI7EJB+Hc3MAxuJRvpaV0CyVMLbUGvKnhXgmSVVUW7RaFVE4FlxNpon1S64HIYTvf+dbTz78kPrCctjz3I6P\u002fef\u002f+MC996znaZqqPv\u002fcU8cO7BEJqiiL4VOPPPD7v\u002fW\u002fffvrXx2uozgAVX3o\u002fvtv\u002fdSfPP\u002fUo8cO7ju4Z+f9P\u002fjOR3\u002f7\u002f\u002fPZT\u002f3p3OxsXfrHF6lPYyTUurgZHs1IbpaqohqW1SgdWySFZUzG+KxmpdxUaSrSNCzilPY3ORE1yxO\u002fpnD8Gsz6oSffva1WU62dVbFo39FdLxSzxw1PGcfkFcqsYNXh3Nwzjzx01Q03O+fYWK\u002fqW1ROcktYBAL1pMGWImFubrYsy7zVarps57PPfv6PPn7ghb2Tmybf9dM\u002f8aFf\u002fPlOt4uToyce1+gJnOzTGlFFtY01ybHyNYM3sIENnC5qZ5va0K5moXHCXXvUr41qXVgxo8Yci\u002fXIVFGrZY3zSRPrF0v21\u002fNeAcqyPHzoQOaYJJNQkNUXnnrk3\u002f2rf\u002f7zf+M3fv5XfmPrWWev7Ydhv196HzxEtAxCCLueffJjf\u002fBbRPThn\u002fk55069tmQYkFJFhKAiIcjxo4e\u002f8pefkCC\u002f\u002frf\u002f\u002ftTUdFV4MBgsLix0Op1Ot7u2YT+KGBs2Y7u7FmMp2RwsMWyqAqlUVSAlMe6SNza8a6qaVSeskVWzpJJzGt7AK58qoVFf1ehaU8 ...

# %%
def weights_init(m):
    if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif isinstance(m, nn.BatchNorm2d):
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

def basic_G(in_channels):
    return nn.Sequential(
        nn.ConvTranspose2d(in_channels, in_channels // 2, kernel_size=4, stride=2, padding=1, bias=False), # H -> 2*H
        nn.BatchNorm2d(in_channels // 2),
        nn.ReLU(True),
    )

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            basic_G(512), # input shape: batch_size * 512 * 4 * 4
            basic_G(256),
            basic_G(128),
            basic_G(64),
            nn.ConvTranspose2d(32, img_channels, 4, 2, 1),
            nn.Tanh(),
        )

        self.label_encoder = nn.Embedding(n_class, 1 * 4 * 4)

        # 每张虚假图片的初始值自z_dim采样，通过latent线性层映射，最终在forward与label的嵌入合并作为input
        self.latent = nn.Linear(z_dim, 511 * 4 * 4)

    def forward(self, z, labels):
        x = self.latent(z)
        c = self.label_encoder(labels)
        input = torch.cat([x, c], dim=1).view(-1, 512, 4, 4)
        return self.net(input)

def basic_D(in_channels):
    return nn.Sequential(
        nn.Conv2d(in_channels, 2 * in_channels, kernel_size=4, stride=2, padding=1, bias=False), # H -> H/2
        nn.BatchNorm2d(2 * in_channels),
        nn.LeakyReLU(0.2, inplace=True),
    )

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.net = nn.Sequential(
            nn.Conv2d(img_channels + 1, 64, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2, inplace=True),
            basic_D(64),
            basic_D(128),
            basic_D(256),
            basic_D(512),
            nn.Conv2d(1024, 1, kernel_size=4, stride=1, padding=0),
            nn.Flatten(),
            nn.Sigmoid(),
        )

        self.label_encoder = nn.Embedding(n_class, 1 * img_dim)

    def forward(self, imgs, labels):
        x = imgs.view(-1, img_channels * img_dim)
        c = self.label_encoder(labels)
        input = torch.cat([x, c], dim=1).view(-1, img_channels + 1, img_size, img_size)

        return self.net(input)

# %%
def train_D(D, D_optimizer, criterion, real_imgs, real_labels, fake_imgs, fake_labels):
    one_targets = torch.ones(batch_size, 1).to(device)
    zero_targets = torch.zeros(batch_size, 1).to(device)

    real_preds = D(real_imgs, real_labels)
    real_loss = criterion(real_preds, one_targets)
    fake_preds = D(fake_imgs.detach(), fake_labels)
    fake_loss = criterion(fake_preds, zero_targets)

    D_loss = real_loss + fake_loss
    D_optimizer.zero_grad()
    D_loss.backward()
    D_optimizer.step()

    real_score = torch.mean(real_preds).item()
    fake_score = torch.mean(fake_preds).item()

    return D_loss.item(), real_score, fake_score

def train_G(D, G_optimizer, criterion, fake_imgs, fake_labels):
    one_targets = torch.ones(fake_imgs.size(0), 1).to(device)

    preds = D(fake_imgs, fake_labels)
    G_loss = criterion(preds, one_targets)

    G_optimizer.zero_grad()
    G_loss.backward()
    G_optimizer.step()

    return G_loss.item()

def fit(D, G, D_optimizer: torch.optim.Adam, G_optimizer: torch.optim.Adam, scheduler, criterion, n_epochs, log_interval):

    train_history = {
        "D_loss": [],
        "G_loss": [],
        "D_real": [],
        "D_fake": [],
        "lr": [],
    }

    seed_seq = np.random.randint(0, 10000, size=n_epochs)


    for epoch in trange(n_epochs, desc="Epoch", leave=False):
        D_loss, G_loss, real_score, fake_score = 0.0, 0.0, 0.0, 0.0

        for real_imgs, real_labels in train_loader:
            real_imgs = real_imgs.to(device)
            real_labels = real_labels.to(device)

            # z = torch.randn(batch_size, z_dim).to(device)
            # 由于在最上方固定随机数种子，因此如果保留上面的代码，模型在每个epoch都会生成相同的fake_labels
            # 这里为了保证可控的随机性，遍历在外部提前生成的随机数序列作为epoch内部需要的随机数种子
            g = torch.Generator().manual_seed(seed)
            z = torch.randn(batch_size, z_dim, generator=g).to(device)
            fake_labels = torch.randint(0, 3, (batch_size, )).to(device)
            fake_imgs = G(z, fake_labels)

            _D_loss, _real_score, _fake_score = train_D(D, D_optimizer, criterion, real_imgs, real_labels, fake_imgs, fake_labels)
            D_loss += _D_loss
            real_score += _real_score
            fake_score += _fake_score

            _G_loss = train_G(D, G_optimizer, criterion, fake_imgs, fake_labels)
            G_loss += _G_loss

        train_history["D_loss"].append(D_loss / n_samples)
        train_history["G_loss"].append(G_loss / n_samples)
        train_history["D_real"].append(real_score / n_batches)
        train_history["D_fake"].append(fake_score / n_batches)

        lr = scheduler.get_last_lr()[0]
        train_history["lr"].append(lr)

        G_optimizer.param_groups[0]['lr'] = lr * k

        if epoch == 0 or (epoch+1) % log_interval == 0:
            clear_output(wait=True)

            tqdm.write(
                f"Epoch [{epoch+1}/{n_epochs}] lr: {train_history['lr'][-1]:.6f} "
                f"D_loss: {train_history['D_loss'][-1]:.4f} G_loss: {train_history['G_loss'][-1]:.4f} "
                f"D_real: {train_history['D_real'][-1]:.4f} D_fake: {train_history['D_fake'][-1]:.4f} "
            )

            z = torch.randn(batch_size, z_dim).to(device)
            # Generate fake labels for showing images
            fake_labels = torch.randint(0, 3, (batch_size, )).to(device)
            fake_imgs = G(z, fake_labels).detach().cpu()
            show_images(fake_imgs)

        scheduler.step()


    return train_history

# %%
D = Discriminator().to(device)
G = Generator().to(device)
D.apply(weights_init)
G.apply(weights_init)

optim_D = torch.optim.Adam(D.parameters(), lr=lr, betas=(0.5, 0.999))
optim_G = torch.optim.Adam(G.parameters(), lr=lr*k, betas=(0.5, 0.999))

v= lambda epoch: 0.9 ** epoch
scheduler = lr_scheduler.LambdaLR(optim_D, lr_lambda=v)
criterion = nn.BCELoss(reduction='sum')

log_interval = 10

train_history = fit(D, G, optim_D, optim_G, scheduler, criterion, n_epochs, log_interval)
# Out:
# Epoch:  98%|█████████▊| 49/50 [12:13<00:14, 14.59s/it]
# Epoch [50/50] lr: 0.000002 D_loss: 0.6083 G_loss: 1.4773 D_real: 0.7546 D_fake: 0.2475
# <div style='display:flex; justify-content:center;'><html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1553f0e3-fad2-4160-a100-3e3fd08fcbfb" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1553f0e3-fad2-4160-a100-3e3fd08fcbfb")) {                    Plotly.newPlot(                        "1553f0e3-fad2-4160-a100-3e3fd08fcbfb",                        [{"name":"0","source":"...\u002fAgCRqA9khQlpTI+5HSkZR0okRZUuakuxMpx\u002fuJRiJ5IiiSoAUNaEWCcITHLnaBxe5ivZnZ8aZ72ld1VT2TGd\u002f98aqqq3t6lhD1L76d7ap6L1+ayMjIiMjIfMCX8CV8CV\u002fCl\u002fAlfAlfwpfwJXwJX8KX8CV8CV\u002fCl\u002fAl\...\u002f1z51980v7jaOH5UzeUWnA00m3WG6QFBgCHSi60Fty9VAgIS66iypY30yEJY6iYLC9HypNEAIVPCIQL5+mJr4TCIKOJ2EtgA4c4BvBMGROPm1dXZQwe8RBFXP27kdClfLCImMqEGSRHSBAKrTHTUC\u002fVYGLGDAQorTDOlsRBLYqm+IZTrcQtQ8zkYWUiRSQNScxloEAUJEyiNAinQT6O\u002fyuSgB0hAhSbOxQjnJ71W51nB4qCHxmwG1sKTQLTYj0Vv5YVLpxeEvzn76rff6O5qtxdGtSMoYDR1e5F5B8\u002fvMQAIWKDzwoCgiOVK0tinEEDqRsC4p\u002fgkKSLENpkqWmVh+Jmzc19+u4qoCAmAFejEOKAkvlrt+f0uzWawc3YeCZIKkoBgAJJxtgSqwUrRTaxxpjP\u002fGq07LVR0fmN9fW6hkyC1LjmHCEgcPl2tHQ5zT5z67DB\u002fNpWvO9FZu+ueN3AoSTPdONtbuGXGASLb\u002fQ\u002fAQBAgqyDqqaq7plgzmppAEaNz3uohEgUOVQiVWwnPZ\u002fHu9tpjT9zy+teGtbzo5\u002fEgYpYWz59dPHCTe2J14b71K59\u002f6leyzt\u002fOz3b+4re0r1b+4KuqJy4desNhiZlTgUIgDJHOharySSxzcWmyeuHszI37ytNbyS03nHryD+9+\u002fdtTmxFRiKm4uhFWmSQxDuKWT1x3RQ\u002fsy7ZMO5mM5wgCweiUtlGyk8a8S7P2\u002fAFMxLcQjIg066HnCkbEBWEAJU7RYSdecYQKCIEYVNA32HrrR\u002f9b+eSF1ScvnPVeRr3+P4FRDhF1T0KiCpzIWon1l3Aph3vwz9CTrt+w68BwNa4KISoOSFeyrkFKAGA9kEQw4SkiANdrpwABku3vjKT4mJLbLF8rFgSslFLMsQHluM67cmUAwAiZvnEESeJKltN6kglQxXHOwJBQwSVSKylY8aKBtp3FCK\u002fUyzWmU5i5RLyvxHlJyqk7MqFGYmch0q3rIAAVgEFUCVGNNrq+CwRIAKAxAsSuqjon4sw3bjtYijoIAZKVXZdPBZWa+JmmGZ0XS\u002fz4+m4Kj0AkwMv55laITAVVnU6HQ964NbwykzpmtTqgNYcTTsYVpW5nKmBElIrR1KsWI0UZgCpe\u002fA\u002f5crRi2VjU1xhiPV0RgDlJKJJoLQc9QHECEecxUqdyjsYyHGg79CTUdC0oYm0\u002fNQAEyAmwYJ3iOhQDAGLJTIAlbg5jVSU2kjKj3tQ6V1EJhEIIKIWEqe5JVRERiKYehOpEB4BC+gaJUU8XW3f5ecTGjTflg6Vut7u1WfVXTl4cdtl0LgK92K2sW\u002fZfDmZL57eKLlJHo88cDBBjMIGQVJ0aI4xO0FloxiuPvPR1WdJ1bt9GCCVUkCRRWn0KRKaZjIR6vVoau7oZicAcCBGebm12\\u002fsM9B6m6uB6PI3vK+vi5T9lcCTbVw994YI2sKi1gFcYDQu5YfgGmhcCNbRoEQUcXVahhGssDDgGhDiZc5rrn1WZWrdMPhpw+O9CSAhBuincxILAHIXHSVJBBXtu5zx4422relJ1YKND92PvrnF6tGteXWnwkLYcaJyIj\u002ft2uuEJEY896zTkCbEmojmIozrQAVX9XqBWGw4XJ84eJmNbiIO9vpu9Nb7nsVzK+cbMX9Rfj0YlK25m+789E\u002fTh+5++qjSyefW\u002fqTb\u002f\u002fIz+qBs6vDc1f09vwCZ+6+XJaEFFFEjQEQqgKZeIMHqsrple9sf+zRv\u002fLks480PF99x2ulmBMMqTKSOwIA6pUxCb\...\u002fdGIgoQYGNp2kB1MGYFA4g6VhaBQAEt4rZr3hXzDc3\u002f\u002ftSN1blICKKd0KiCgGAWIAANAJGhhI0A22kAIvQmhAsCzRnjrEKVmM8iLMqnHy6HIysINZ3ytVYMZVavF5D\u002fhGISnBEHYHZj57phMxZHBFrrPCP9E0g5Vi6KJxglx9lAuEkg9rYqOrrEWx7DH9S5Pi59U+sh5lVFt76WsTz4dLVKrn9JmmHGEIoV\u002fP+5sZwuLV4m5gcvq1TOGZwiqguFpdjLKUy0jSaERSEkcqtKrTg2rN3bzxzdGbWYvO4679IQTqkT\u002fxcRJBa+wSAenIn5Ki6rePSfjkykRSGVfrqdPfB5ZuOFWsJ\u002fayLrawjChk5Quq2KXx\u002ftrFqRci5UllZ1f4\u002f1ncd5KA0do7WbYjB32BvvS2\u002fXM0KxW4pA7lRbipgexP1lVAXslvwbAyEgZBZGuHGky8AKLDyp\u002fCJhT80wOr\u002fJIiAGUbmBQESAVRiVQLJCkWsAKAMiFa2K3vh3\u002f+H4W+\u002fqI4ASmA46BHwEABqGVTSQTxjvaWff9fq4HJfBsESmguDYe9SkZsxsh4sgTCDJFw887SHM5CM0SynWWXVofJjDz3x4vITL37z3fuRRfidtoLEGAzl9KW6f411\u002f456eaT9TBIpRJE4zijYIpDiZyQAZsETI3Ps+mqroDYIt397zHTmm87EaLQiVtFZoTlUCKItFo5lEwlHwDtcfKaZOChZIMS8i1gUzM9eOCSwAFQW\u002fvHpU+9+13+6cmW99Y7Z+kEHVFVAU5KOqnUowKLUbihtIktEVA4dO3q0e\u002fNWtvS7f\u002fy0i0uFy2duHpQLMHAygicgEC+4furvcXSV2yWEWQ9\u002flQZFFEnNGEGc0zxx+y+snUlu7WjovyP\u002flFMVOfIqnUtvXPjKE7MNafr2X\u002fyrSfORYFtLg\u0 ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=1, cols=3, subplot_titles=("Loss", "D(x) & D(G(z))", "Learning Rate"))

fig.add_traces([
    go.Scatter(y=train_history["D_loss"], mode='lines', name='D_loss'),
    go.Scatter(y=train_history["G_loss"], mode='lines', name='G_loss'),
], rows=1, cols=1)

fig.add_traces([
    go.Scatter(y=train_history["D_real"], mode='lines', name='D(x)'),
    go.Scatter(y=train_history["D_fake"], mode='lines', name='D(G(z))'),
], rows=1, cols=2)

fig.add_hline(
    y=0.5,
    line=dict(color="black", dash="dash"),
    row=1,
    col=2,
)

fig.add_trace(
    go.Scatter(y=train_history["lr"], mode='lines', name='Learning Rate'),
    row=1,
    col=3,
)

fig.update_layout(height=400, width=1200, title_text="GAN Training History")
show_centered(fig)
# Out:
# <div style='display:flex; justify-content:center;'><html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="58afc2e2-f17a-4499-872a-029c71f1caf3" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58afc2e2-f17a-4499-872a-029c71f1caf3")) {                    Plotly.newPlot(                        "58afc2e2-f17a-4499-872a-029c71f1caf3",                        [{"mode":"lines","name":"D_loss","y":[23.01848887034825,1.311192600310795,1.0829875302693202,0.8820812376718673,0.687596260933649,1.0682879088416932,1.091186107151092,1.1273778741321867,1.1313002147371807,1.0980629822564503,1.0826483681088401,1.0529833445473322,1.0158227640485007,1.008893254446605,1.022987013014536,0.9570204144432432,0.9551547186715262,0.9562437821948339,0.9044366412692599,0.8682381523980035,0.8904544883304172,0.8635088375636509,0.8368831876724485,0.8081984073396713,0.7960931497906881,0.7640540145692372,0.7696189535988702,0.7978659444385104,0.7587710070231605,0.7341195545499287,0.7545912542040386,0.7303925177407643,0.7199417038569375,0.699425538759383,0.7095104285648891,0.6538416960882762,0.6463419725024511,0.6639488329963078,0.6325242708599756,0.6294917545621357,0.6416869390578497,0.6162673352256653,0.6142633581918383,0.5995969310639396,0.6227078165326799,0.6283841553188506,0.5796506541115897,0.6100485090225461,0.6018485038999527,0.6082927605462453],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines","name":"G_loss","y":[8.320221046629799,2.840675579933893,3.179486972945077,3.740131167759971,4.384991578828721,2.936898125542535,2.213793550218855,2.032034722585527,1.812635536420913,1.7011974130358014,1.7255426391722664,1.7294888579656207,1.6677835214705694,1.6856782103341723,1.6394612789154053,1.607485899092659,1.591561726161412,1.5649741104670933,1.5439725527687678,1.5475798220861525,1.5810373260861352,1.5371684460412889,1.5546514072115458,1.524617660613287,1.5388323511396136,1.5297294011191716,1.5200285487704808,1.481745984062316,1.4787881707388257,1.49264818448869,1.4406705523294117,1.443561625859094,1.4648260934012276,1.4630656931135388,1.4432238533383324,1.509071337230622,1.4904022920699347,1.4577131135123116,1.4679112510075645,1.48415251080952,1.468450307089185,1.4864836026751806,1.4856471546112544,1.5074118371993777,1.4502389029851035,1.451893368978349,1.5141732715425038,1.4723643333192855,1.4774752291422042,1.4773443320440867],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines","name":"D(x)","y":[0.6931218977956919,0.6836328978817432,0.7164062966043369,0.7669765124431788,0.8185866289318372,0.6911326373616854,0.6569493858095927,0.6481878132774279,0.6367409624732457,0.6385117744406065,0.6431378087936304,0.6512350728496527,0.6527690448057957,0.6579779226046342,0.6543968938864194,0.6672467276071891,0.6658235845657495,0.6697615350668247,0.679061967975054,0.6836487551530203,0.6850528560387783,0.6875052990821692,0.6980154506671123,0.700725603562135,0.7046652974990698,0.710644639073274,0.7113557568727396,0.7044977526634167,0.7157594905449793,0.7176888237396876,0.7130400488773981,0.7170928552364692,0.7235386279913095,0.7281917857053952,0.7248690483661798,0.7417906706149762,0.7445902209251355,0.734845757484436,0.7447206232792292,0.745734745875383,0.745914842073734,0.7502990708901331,0.7532881337862748,0.757349390632067,0.7475469509760538,0.7474503383422509,0.761129610813581,0.7541396182317001,0.7530702757529724,0.7545534486954029],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"lines","name":"D(G(z))","y":[0.4741850349938688,0.34580369465626204,0.2925917269088901,0.23674882674971834,0.19192844296533926,0.30094618355043423,0.3392580944376114,0.35284281923220706,0.36704494517583114,0.36207564136920833,0.35611041004841143,0.35267203415815646,0.3433991164351121,0.34494876293226695,0.3458383731926099,0.33276250614569736,0.3324118117109323,0.332059 ...
