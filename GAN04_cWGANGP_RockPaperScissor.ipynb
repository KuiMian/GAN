# %% [markdown]
# **Train cWGAN-GP with Rock-Paper-Scissor Dataset**
#
# ---
#
# You can get dataset from [Rock-Paper-Scissor, Kaggle](https://www.kaggle.com/datasets/sanikamal/rock-paper-scissors-dataset).

# %%
import numpy as np
import pandas as pd
import plotly.express as px

import torch
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import DataLoader, Subset

from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torchvision import transforms as T

from tqdm import trange, tqdm

from IPython.display import clear_output

from multiprocessing import cpu_count

# %%
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

img_size = 128
img_dim = img_size ** 2
img_channels = 3
n_class = 3

z_dim = 100

n_epochs = 200
batch_size = 32
lr = 4e-4
n_critic = 1 # D每更新n_critic次，G更新一次
lambda_gp = 10 # 控制梯度衰减的强度

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
print(f"Cpu core num: {cpu_count()}")
# Out:
# Using device: cuda
# Cpu core num: 2

# %%
def download_dataset_to_dir(dataset_id: str, move: bool = True, target_dir: str = "./data/"):
    """
    使用 kagglehub 下载 Kaggle 数据集，并移动/复制到指定目录
    :param dataset_id: Kaggle 数据集 ID，比如 "splcher/animefacedataset"
    :param move: True=剪切数据至target_dir，False=数据位置不变
    :param target_dir: 目标目录，比如 "./data"
    :return: 目标目录的绝对路径
    """

    import kagglehub
    import shutil
    import os

    # 下载/获取缓存路径
    cache_path = kagglehub.dataset_download(dataset_id)
    print(f"Download path: {cache_path}")

    if not move:
        return cache_path
    else:
        # 确保目标目录存在
        os.makedirs(target_dir, exist_ok=True)

        # 移动内容
        for item in os.listdir(cache_path):
            s = os.path.join(cache_path, item)
            d = os.path.join(target_dir, item)

            # 剪切（移动）
            if os.path.exists(d):
                if os.path.isdir(d):
                    shutil.rmtree(d)
                else:
                    os.remove(d)
            shutil.move(s, d)

        return os.path.abspath(target_dir)

data_path = download_dataset_to_dir("sanikamal/rock-paper-scissors-dataset", move=False, target_dir="./data/rockpaperscissors/")
# Out:
# Using Colab cache for faster access to the 'rock-paper-scissors-dataset' dataset.
# Download path: /kaggle/input/rock-paper-scissors-dataset

# %%
train_dataset = ImageFolder(root=data_path + '/Rock-Paper-Scissors/train', transform=T.Compose(
        [
            T.Resize(img_size),
            T.ToTensor(),
            T.Normalize([0.5] * 3, [0.5] * 3),
        ]
    ))

subset_flag = True
subset_size = 200

data_loader_paras = {
    "batch_size": batch_size,
    "shuffle": True,
    "drop_last": True,

    "num_workers": 2,
    "pin_memory": True,
}

if subset_flag:
    indices = np.random.choice(range(len(train_dataset)), subset_size)
    subset_dataset = Subset(train_dataset, indices)
    print(f"Subset dataset size: {len(subset_dataset)}")

    train_loader = DataLoader(subset_dataset, **data_loader_paras)
else:
    train_loader = DataLoader(train_dataset, **data_loader_paras)

n_samples = len(train_loader.dataset)
n_batches = len(train_loader)
print(f"Number of training samples: {n_samples}")
print(f"Number of batches: {n_batches}")
# Out:
# Subset dataset size: 200
# Number of training samples: 200
# Number of batches: 6

# %%
imgs, labels = next(iter(train_loader))
print(f"Image batch shape: {imgs.shape}")
print(f"Label batch shape: {labels.shape}")
# Out:
# Image batch shape: torch.Size([32, 3, 128, 128])
# Label batch shape: torch.Size([32])

# %%
from IPython.display import display, HTML

def show_centered(fig):
    html = f"<div style='display:flex; justify-content:center;'>{fig.to_html(include_plotlyjs='cdn')}</div>"
    display(HTML(html))

# %%
def denormalize(imgs):
    return imgs * 0.5 + 0.5

def show_images(imgs, grid_size=5):
    grid_imgs = make_grid(denormalize(imgs)[:24], nrow=6, padding=2).permute(1, 2, 0)

    fig = px.imshow(grid_imgs, aspect='auto')
    fig.update_xaxes(showticklabels=False).update_yaxes(showticklabels=False)
    fig.update_layout(
        width=800,
        height=400,
        title=dict(
            text="Rock-Paper-Scissor",
            x=0.5,
            xanchor='center',
            yanchor='top',
        ),
        coloraxis_showscale=False,
    )

    show_centered(fig)

show_images(imgs)
# Out:
# <div style='display:flex; justify-content:center;'><html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4c6e2d92-a3f4-47bd-9453-2faab870c6e5" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c6e2d92-a3f4-47bd-9453-2faab870c6e5")) {                    Plotly.newPlot(                        "4c6e2d92-a3f4-47bd-9453-2faab870c6e5",                        [{"name":"0","source":"...\u002fCwzfo\u002fjx49yDw+\u002fHh4eAPdxH\u002fdxH\u002fdxH\u002fdxH\u002fdxH\u002fdxH\u002fdxH\u002fdxH\u002fdxH7cLDH9E5Gb6fdxVICIAeO9DIqJWL4h4R2oqCKlKC+lIiWZMJNYwO\...\u002fR8RNQOm2VOtzYCPw5j7uI8fadyfVfoEodmL1dDswm5ZZDZmF4\u002f9\...\u002fNijLMvBzsA71+l1W+1WPftvAT6uWSURmfG6731MROynELGarjLM6OZqaPZ6teIiMkNa1YaJnDVik6GGaQxBS9PaGkLxZlhqBW8pJ6DKVjNsosAQumpMIqb5tRc0pdWIExkiom2Rcktjbsnw0VFTMbGR1BpPkzjR8UgMiWkV1yw7seJmIAZ2WsFp9IjgS9VCvJ2LN2K2lomYqGUicRo+hNL7+DEGe99fWR2urGxcuXzh\u002feP5cFjn+FuAj2VWKR+OVpdXRoPBvoP7F\u002ffvJ7q9AZn3fjQYsnCn01H6w1goYaAmQkr9OF32E\u002fu7qoOxO5bGT8kZaIoNZSM9iK0pqjJMQ2AIzLPtqYmaZn9VYDitpW9pUsQ05iqxxjOR\u002f3bR9Ktq+TR3Ir1ZPGJGVsReeGYgBnxilEJuM7C3jOFEYkQUWz29mWVMj8eAqiU1FUHCRDlV1Pyt8YuIiAyHg9FgaJKk1+uRUlWGKn8zJrfUPhsTTQoIwmu+N+ulhlqp+7iPAFfk+fKV0dbmyJXbg2GWmYc\u002f9dlaU\u002f+xx4cZiMxGPhxeP3dx7erVtevXTon92d\u002f4zcMPP1Jnmo58OLp08sTpd97d2lx\u002f\u002fNNPf+5Lv9TuzdWZpkNE+ltbl8+cXb500bpy6cCBh558av\u002fhIz8S9Rq7qmpvdVs9V7X3jNKqff1EzoBm3xqJUVQkTkvUxH6sPW\u002fTr9m6J
fKDIlAj8QaVpaXv\u002fvVvzp38v35hflf\u002f0\u002f\u002f7mc+\u002f1OqsYQgyqwKD6cwPRowKSDTOO\u002fjPmx\u002fx5aOVSLEjEpUSkmH3ejqe28\u002f+lM\u002fl3V79QIAAMDeD9ZWN65cHGxvlwAby8vqC19Y2Levzvejgzs+VAKhhExLgzOpTVvtrNNjN9juj9597lsk\u002fFP\u002fyZfTdqdeahfD7e211c2ysMSFL\u002fsghVeiCC+ffPfYs4s\u002f+3t\u002fP2nNek2RPedbO9ubm8PRoBgNDfnFpZ6zrdEoH436r33nG0maPvnTXyQiW9o3Xnrl3ZdfwmK4ee6029n65X\u002f0+535hbrEu44ZHdxE1Jhjpxm79Wq\u002ffFuSZ2Ba\u002f17F3h2JPXuVMk1FLSt619QVKdUI1HJnGDmRPpEI0+nNO9kM16BxM46YaDyArF5ffvuV17c3Nh587OHP\u002fezPtLvdGtsMXU3ckj8wVI2p8YesKdbeNG6oIlBm\u002f0KFScGpppuQyrUQKLWWMKP4jKwxRK5ePD\u002fc3tStrvaoQYET77wHOPneuyffO\u002fbFX\u002fzlYEC0IdoTMCPUK8vX\u002f+2\u002f\u002fOdvvfBSoskQ3Lh2+b\u002f5P\u002f2zR598alqRSK8Fp1ZZVUykVyuonvdjh+jjtK ...

# %%
def weights_init(m):
    if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif isinstance(m, nn.BatchNorm2d):
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

def basic_G(in_channels):
    return nn.Sequential(
        nn.ConvTranspose2d(in_channels, in_channels // 2, kernel_size=4, stride=2, padding=1, bias=False), # H -> 2*H
        nn.BatchNorm2d(in_channels // 2),
        nn.ReLU(True),
    )

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            basic_G(512), # input shape: batch_size * 512 * 4 * 4
            basic_G(256),
            basic_G(128),
            basic_G(64),
            nn.ConvTranspose2d(32, img_channels, 4, 2, 1),
            nn.Tanh(),
        )

        self.label_encoder = nn.Embedding(n_class, 1 * 4 * 4)

        # 每张虚假图片的初始值自z_dim采样，通过latent线性层映射，最终在forward与label的嵌入合并作为input
        self.latent = nn.Linear(z_dim, 511 * 4 * 4)

    def forward(self, z, labels):
        x = self.latent(z)
        c = self.label_encoder(labels)
        input = torch.cat([x, c], dim=1).view(-1, 512, 4, 4)
        return self.net(input)

def basic_D(in_channels):
    return nn.Sequential(
        nn.Conv2d(in_channels, 2 * in_channels, kernel_size=4, stride=2, padding=1, bias=False), # H -> H/2
        nn.InstanceNorm2d(2 * in_channels), # 注意这里不是BatchNorm2d!!!
        nn.LeakyReLU(0.2, inplace=True),
    )

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.net = nn.Sequential(
            nn.Conv2d(img_channels + 1, 64, kernel_size=4, stride=2, padding=1),
            # nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2, inplace=True),
            basic_D(64),
            basic_D(128),
            basic_D(256),
            basic_D(512),
            nn.Conv2d(1024, 1, kernel_size=4, stride=1, padding=0),
            nn.Flatten(),
            # nn.Sigmoid(),
        )

        self.label_encoder = nn.Embedding(n_class, 1 * img_dim)

    def forward(self, imgs, labels):
        x = imgs.view(-1, img_channels * img_dim)
        c = self.label_encoder(labels)
        input = torch.cat([x, c], dim=1).view(-1, img_channels + 1, img_size, img_size)

        return self.net(input)

# %%
def gradient_penalty(D, real_imgs, fake_imgs, fake_labels):
    epsilon = torch.rand(batch_size, 1, 1, 1, device=device)
    interpolated = epsilon * real_imgs + (1 - epsilon) * fake_imgs
    interpolated.requires_grad_(True)
    output_D = D(interpolated, fake_labels)

    gradients = torch.autograd.grad(
        outputs=output_D,
        inputs=interpolated,
        grad_outputs=torch.ones_like(output_D),
        create_graph=True,
        retain_graph=True,
        only_inputs=True,
    )[0]

    gradients = gradients.view(batch_size, -1)
    gradient_norm = gradients.norm(2, dim=1)
    gp = torch.mean((gradient_norm - 1) ** 2)

    return gp

# %%
def train_D(D, D_optimizer, real_imgs, real_labels, fake_imgs, fake_labels):
    for i in range(n_critic):
        real_preds = D(real_imgs, real_labels)
        fake_preds = D(fake_imgs.detach(), fake_labels.detach())

        real_score = torch.mean(real_preds)
        fake_score = torch.mean(fake_preds)

        gp = gradient_penalty(D, real_imgs, fake_imgs, fake_labels)

        D_loss = - real_score + fake_score + lambda_gp * gp
        D_optimizer.zero_grad()
        D_loss.backward(retain_graph=True) # Add retain_graph=True here
        D_optimizer.step()

    return D_loss.item(), real_score.item(), fake_score.item()

def train_G(D, G_optimizer, fake_imgs, fake_labels):
    preds = D(fake_imgs, fake_labels)
    G_loss = - torch.mean(preds)

    G_optimizer.zero_grad()
    G_loss.backward()
    G_optimizer.step()

    return G_loss.item()

def fit(D, G, D_optimizer, G_optimizer, n_epochs, log_interval):

    train_history = {
        "D_loss": [],
        "G_loss": [],
        "D_real": [],
        "D_fake": [],
        "lr": [],
    }

    seed_seq = np.random.randint(0, 10000, size=n_epochs)


    for epoch in trange(n_epochs, desc="Epoch", leave=False):
        D_loss, G_loss, real_score, fake_score = 0.0, 0.0, 0.0, 0.0

        for real_imgs, real_labels in train_loader:
            real_imgs = real_imgs.to(device)
            real_labels = real_labels.to(device)

            # z = torch.randn(batch_size, z_dim).to(device)
            # 由于在最上方固定随机数种子，因此如果保留上面的代码，模型在每个epoch都会生成相同的fake_labels
            # 这里为了保证可控的随机性，遍历在外部提前生成的随机数序列作为epoch内部需要的随机数种子
            g = torch.Generator().manual_seed(seed)
            z = torch.randn(batch_size, z_dim, generator=g).to(device)
            fake_labels = torch.randint(0, n_class, (batch_size, )).to(device)
            fake_imgs = G(z, fake_labels)

            _D_loss, _real_score, _fake_score = train_D(D, D_optimizer, real_imgs, real_labels, fake_imgs, fake_labels)
            D_loss += _D_loss
            real_score += _real_score
            fake_score += _fake_score

            _G_loss = train_G(D, G_optimizer, fake_imgs, fake_labels)
            G_loss += _G_loss

        train_history["D_loss"].append(D_loss / n_samples)
        train_history["G_loss"].append(G_loss / n_samples)
        train_history["D_real"].append(real_score / n_batches)
        train_history["D_fake"].append(fake_score / n_batches)

        train_history["lr"].append(lr)


        if epoch == 0 or (epoch+1) % log_interval == 0:
            clear_output(wait=True)

            tqdm.write(
                f"Epoch [{epoch+1}/{n_epochs}] lr: {train_history['lr'][-1]:.6f} "
                f"D_loss: {train_history['D_loss'][-1]:.4f} G_loss: {train_history['G_loss'][-1]:.4f} "
                f"D_real: {train_history['D_real'][-1]:.4f} D_fake: {train_history['D_fake'][-1]:.4f} "
            )

            z = torch.randn(batch_size, z_dim).to(device)
            # Generate fake labels for showing images
            fake_labels = torch.randint(0, 3, (batch_size, )).to(device)
            fake_imgs = G(z, fake_labels).detach().cpu()
            show_images(fake_imgs)

    return train_history

# %%
D = Discriminator().to(device)
G = Generator().to(device)
D.apply(weights_init)
G.apply(weights_init)

optim_D = Adam(D.parameters(), lr=lr)
optim_G = Adam(G.parameters(), lr=lr)

log_interval = 10

train_history = fit(D, G, optim_D, optim_G, n_epochs, log_interval)
# Out:
# Epoch: 100%|█████████▉| 199/200 [07:11<00:02,  2.12s/it]
# Epoch [200/200] lr: 0.000400 D_loss: -9.5824 G_loss: 17.5432 D_real: -244.0974 D_fake: -584.4632
# <div style='display:flex; justify-content:center;'><html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="02f62b56-a9be-4058-8c38-263b0fa7ab06" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02f62b56-a9be-4058-8c38-263b0fa7ab06")) {                    Plotly.newPlot(                        "02f62b56-a9be-4058-8c38-263b0fa7ab06",                        [{"name":"0","source":"...\u002foFkl70on4Sn\u002fRCoyhSaLLJBtAgQYAkhjsPOOfcM9a4xzXmEIN\u002feohca6\u002fatatqV91zcO5tna92rZUrMjLSw93Dw8MjMpLoU3yKT\u002fEpPsWn+BSf4lN8ik\u002fxKT7Fp\u002fgUn+JTfIrnBeev+6d3b0xvgcBExEwgEJiYmIkIABNAzEQKCBOYOefZ5FOCbK5VgKHYXCssxMyUS83F5HR+vBwQhDkThvyVr+2vo4t0ymXmPLn0zfFOJsrXEmHzq\u002f\u002fOWQD0tJEQ5ZuAKNd3J3+mB5siN2X29wVv7tfXg4go8wE5T+ZPf6+cLpxzzhbHt2+8TkQPTu8d7t0Ccs7+LsK0Lbm\u002fSX\u002fHCyk8iavPSN9QRcxMrFnKGwqF+UIT+lrtSDlzridtUxuiDZ19+Zvr+jLpkfzUc\u002fsi\u002fdH6ApSz7NCZy3xSvTKd2\u002fI3+elRbbyiXuil8Bo9LgVQrxsXtdit3QVVO8dPzC\u002fEu+kbfeu5lCnspYDH2lpf5iVub7RtW87meFcKl+67y9VHyu\u002fpuaR1V+e\u002fuvxtOj0iHQWYFDn\u002fNr2vb88rutwWbgJZX\u002fpyL3Fph\u002fOPco+YN5Zqm2eX2q1OKoEBYt7oNud\u002fu1T1HH6M2h3O518Xx0wEYiIg6+Lj12Kbn0BZD3uaOZeRpbzJf2FJNuVc1HfDTSWVXT4AYCYiBcxWCrSxzBspbOve84EZoPni+PbN14no4dn9w+lNEG31LVOXxYK+prTRH86\u002fQRdSoJ5zRDnnThnb\u002fPl\u002fn2fDpfzjIv3i2swlbGv0uE7uSjMXs82\u002fK\u002f3NvaiX+JZOXL
AQDJtaNFK60SE\u002fCZZo22E3vafuZ5Or1sWXq9ni3XjsniZmZSESIQeAdyyqMvFiWWJkjIAlESEoEFMwiuo0qPY8UPhZsjCcRAdSPdzg32q2WMdFWmYjQL8nlnhObHBvO7CQ\u002fgsdTd3W7T7m4YX8+05CtTk\u002fPI7LY3HKT1v++dHaTtGvN0DeFjybC2tOZ2+Dlkx8Bel5tfmXBZW5sb7dT2yvwJOnkhOy89Fl2Tz8Bu\u002fTw5g9EQsxKWVr9AREzM7GAe5csO0wCpt3emYie22+9nDn\u002fvpxKtHEMAKIn+fIbbDP+3GBTa4BISUHZPc2uUP7MZ\u002ftKgYkYxAoCGJCc+QLbnJ8ULlzpq6T5s4ndwRzRNtxGuzW4NCa5OMGEbX03F37iUtjFzxAp1wYek0LP9+03EfJoItsHBrhvCy8W2\u002fsUV2LDT86WJ\u002fMWBDAhP\u002fQmBFGwAqSc1wQgW6dcws\u002fAKpmNboCot0vbSQoQARtblSknyo06k32Z+Mu\u002fnx+PGofeklz6fCTH5vvK9G298nH\u002fj9GXfCGFnwr9rQHkJTHP6ok\u002fCvShz4\u002f0Rn0l+qPnBDYcViLKQQ3kHpmIAZBybizZY9k4WXTRv\u002fRRJcFzuJpXjCx3PvsUZgJEhAjUe82Xr7oEJspP+v28oFcGEEGhqgQlY0RBQkLARtdz5RmGhQlEQqxMxKpkuBdQX+AnXP1ejj9\u002fUtgcb4YSlyqw+SlEyKPtnuV95NvwRYjj8as\u002fSfwMkXJt9GP6HdJ ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=1, cols=3, subplot_titles=("Loss", "D(x) & D(G(z))", "Learning Rate"))

fig.add_traces([
    go.Scatter(y=train_history["D_loss"], mode='lines', name='D_loss'),
    go.Scatter(y=train_history["G_loss"], mode='lines', name='G_loss'),
], rows=1, cols=1)

fig.add_traces([
    go.Scatter(y=train_history["D_real"], mode='lines', name='D(x)'),
    go.Scatter(y=train_history["D_fake"], mode='lines', name='D(G(z))'),
], rows=1, cols=2)

fig.add_hline(
    y=0.5,
    line=dict(color="black", dash="dash"),
    row=1,
    col=2,
)

fig.add_trace(
    go.Scatter(y=train_history["lr"], mode='lines', name='Learning Rate'),
    row=1,
    col=3,
)

fig.update_layout(height=400, width=1200, title_text="GAN Training History")
show_centered(fig)
# Out:
# <div style='display:flex; justify-content:center;'><html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6b11ca11-5d77-46e8-a280-f11374b0ad90" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b11ca11-5d77-46e8-a280-f11374b0ad90")) {                    Plotly.newPlot(                        "6b11ca11-5d77-46e8-a280-f11374b0ad90",                        [{"mode":"lines","name":"D_loss","y":[-0.1457284450531006,-1.9215460777282716,-3.8647004699707033,-5.083389358520508,-5.38431396484375,-5.484109725952148,-4.681645355224609,-4.07113410949707,-4.084821014404297,-4.204989471435547,-4.424964218139649,-4.553570861816406,-4.444541549682617,-4.61538070678711,-4.375250396728515,-3.9536123275756836,-3.467151527404785,-3.4733443